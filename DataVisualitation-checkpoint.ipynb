# %%
import matplotlib.pyplot as plt 
import pandas as pd 
A = [22,24,27,25,26] 
B = [21,22,23,24,25] 
C = [1,2,3,4,5] 
plt.scatter(C,A)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.scatter(C,A, color = 'Red', marker = 'o', label ='Person A') 
plt.scatter(C,B, color = 'Blue', marker = 'D', label ='Person B') 
plt.xlabel('Months') 
plt.ylabel('Products sold') 
plt.title('Sales Performance A') 
ptl.legend()
plt.grid() # to add reference lines plt.show() # to hide this <matplotlib.collections.PathCollection at 0x173ad5640>
ptl.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 6
#       4 plt.ylabel('Products sold')
#       5 plt.title('Sales Performance A')
# ----> 6 ptl.legend()
#       7 plt.grid() # to add reference lines plt.show() # to hide this <matplotlib.collections.PathCollection at 0x173ad5640>
#       8 ptl.show()
#
# NameError: name 'ptl' is not defined

# %%
fig, axs = ptl.subplots(2,2)
axs(0,0).scatter

# %%
import pandas as pd

# %%
df1= pd.read_csv('Auto.csv')
df1
# Out:
#       mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0    18.0        8.0         307.0         130    3504          12.0    70
# 1    15.0        8.0         350.0         165    3693          11.5    70
# 2     NaN        8.0         318.0         150    3436          11.0    70
# 3     NaN        8.0           NaN         150    3433          12.0    70
# 4     NaN        8.0           NaN         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0        4.0         140.0          86    2790          15.6    82
# 393  44.0        4.0          97.0          52    2130          24.6    82
# 394  32.0        4.0         135.0          84    2295          11.6    82
# 395  28.0        4.0         120.0          79    2625          18.6    82
# 396  31.0        4.0         119.0          82    2720          19.4    82
#
#      origin                       name
# ...

# %%
df1.head()
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
# 2   NaN        8.0         318.0         150    3436          11.0    70
# 3   NaN        8.0           NaN         150    3433          12.0    70
# 4   NaN        8.0           NaN         140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df1.head(10)
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
# 2   NaN        8.0         318.0         150    3436          11.0    70
# 3   NaN        8.0           NaN         150    3433          12.0    70
# 4   NaN        8.0           NaN         140    3449          10.5    70
# 5   NaN        8.0           NaN         198    4341          10.0    70
# 6   NaN        8.0           NaN         220    4354           9.0    70
# 7  14.0        8.0           NaN         215    4312           8.5    70
# 8  14.0        8.0         455.0         225    4425          10.0    70
# 9  15.0        8.0         390.0         190    3850           8.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# ...

# %%
df1.tail()
# Out:
#       mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 392  27.0        4.0         140.0          86    2790          15.6    82
# 393  44.0        4.0          97.0          52    2130          24.6    82
# 394  32.0        4.0         135.0          84    2295          11.6    82
# 395  28.0        4.0         120.0          79    2625          18.6    82
# 396  31.0        4.0         119.0          82    2720          19.4    82
#
#      origin             name
# 392       1  ford mustang gl
# 393       2        vw pickup
# 394       1    dodge rampage
# 395       1      ford ranger
# 396       1       chevy s-10

# %%
df1.tail(5)
# Out:
#       mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 392  27.0        4.0         140.0          86    2790          15.6    82
# 393  44.0        4.0          97.0          52    2130          24.6    82
# 394  32.0        4.0         135.0          84    2295          11.6    82
# 395  28.0        4.0         120.0          79    2625          18.6    82
# 396  31.0        4.0         119.0          82    2720          19.4    82
#
#      origin             name
# 392       1  ford mustang gl
# 393       2        vw pickup
# 394       1    dodge rampage
# 395       1      ford ranger
# 396       1       chevy s-10

# %%
df1.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'Horse Power', 'weight',
#        'acceleration', 'year', 'origin', 'name'],
#       dtype='object')

# %%
df1.shape
# Out:
# (397, 9)

# %%
df1.dtypes
# Out:
# mpg             float64
# cylinders       float64
# displacement    float64
# Horse Power      object
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %%
df1.isnull
# Out:
# <bound method DataFrame.isnull of       mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0    18.0        8.0         307.0         130    3504          12.0    70
# 1    15.0        8.0         350.0         165    3693          11.5    70
# 2     NaN        8.0         318.0         150    3436          11.0    70
# 3     NaN        8.0           NaN         150    3433          12.0    70
# 4     NaN        8.0           NaN         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0        4.0         140.0          86    2790          15.6    82
# 393  44.0        4.0          97.0          52    2130          24.6    82
# 394  32.0        4.0         135.0          84    2295          11.6    82
# 395  28.0        4.0         120.0          79    2625          18.6    82
# 396  31.0        4.0         119.0          82    2720          19.4    82
#
# ...

# %%
df1.isnull().sum()
# Out:
# mpg             5
# cylinders       3
# displacement    5
# Horse Power     0
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %%
df1.count()
# Out:
# mpg             392
# cylinders       394
# displacement    392
# Horse Power     397
# weight          397
# acceleration    397
# year            397
# origin          397
# name            397
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     394 non-null    float64
#  2   displacement  392 non-null    float64
#  3   Horse Power   397 non-null    object
#  4   weight        397 non-null    int64
#  5   acceleration  397 non-null    float64
#  6   year          397 non-null    int64
#  7   origin        397 non-null    int64
#  8   name          397 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.0+ KB

# %%
df1.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  392.000000  394.000000    392.000000   397.000000    397.000000
# mean    23.611735    5.439086    191.080357  2970.261965     15.555668
# std      7.827466    1.693452    102.452019   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    100.750000  2223.000000     13.800000
# 50%     23.000000    4.000000    145.500000  2800.000000     15.500000
# 75%     29.000000    8.000000    260.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df1.mpg
# Out:
# 0      18.0
# 1      15.0
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 392    27.0
# 393    44.0
# 394    32.0
# 395    28.0
# 396    31.0
# Name: mpg, Length: 397, dtype: float64

# %%
x = df1['mpg']
type(x)
# Out:
# pandas.core.series.Series

# %%
df1['mpg']
# Out:
# 0      18.0
# 1      15.0
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 392    27.0
# 393    44.0
# 394    32.0
# 395    28.0
# 396    31.0
# Name: mpg, Length: 397, dtype: float64

# %%
df1[['mpg','acceleration','weight']]
# Out:
#       mpg  acceleration  weight
# 0    18.0          12.0    3504
# 1    15.0          11.5    3693
# 2     NaN          11.0    3436
# 3     NaN          12.0    3433
# 4     NaN          10.5    3449
# ..    ...           ...     ...
# 392  27.0          15.6    2790
# 393  44.0          24.6    2130
# 394  32.0          11.6    2295
# 395  28.0          18.6    2625
# 396  31.0          19.4    2720
#
# [397 rows x 3 columns]

# %%
df1['mpg'].mean()
# Out:
# np.float64(23.611734693877548)

# %%
 df1[['mpg','acceleration','weight']].min()
# Out:
# mpg                9.0
# acceleration       8.0
# weight          1613.0
# dtype: float64

# %%
#### Feature Engineering  sql price

# %%
df1.head(2)
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320

# %%
df1['acceleration'] + df1['origin']
# Out:
# 0      13.0
# 1      12.5
# 2      12.0
# 3      13.0
# 4      11.5
#        ...
# 392    16.6
# 393    26.6
# 394    12.6
# 395    19.6
# 396    20.4
# Length: 397, dtype: float64

# %%
df1['col1']= df1['acceleration'] + df1['origin']  # any opreation are used
df1.head(2)
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
#
#    origin                       name  col1
# 0       1  chevrolet chevelle malibu  13.0
# 1       1          buick skylark 320  12.5

# %%
df1['col2'] = df1['acceleration'] **2
df1.head()
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
# 2   NaN        8.0         318.0         150    3436          11.0    70
# 3   NaN        8.0           NaN         150    3433          12.0    70
# 4   NaN        8.0           NaN         140    3449          10.5    70
#
#    origin                       name  col1    col2
# 0       1  chevrolet chevelle malibu  13.0  144.00
# 1       1          buick skylark 320  12.5  132.25
# 2       1         plymouth satellite  12.0  121.00
# 3       1              amc rebel sst  13.0  144.00
# 4       1                ford torino  11.5  110.25

# %%
df1['col2'] = df1['acceleration'] **3
df1.head()
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
# 2   NaN        8.0         318.0         150    3436          11.0    70
# 3   NaN        8.0           NaN         150    3433          12.0    70
# 4   NaN        8.0           NaN         140    3449          10.5    70
#
#    origin                       name  col1      col2
# 0       1  chevrolet chevelle malibu  13.0  1728.000
# 1       1          buick skylark 320  12.5  1520.875
# 2       1         plymouth satellite  12.0  1331.000
# 3       1              amc rebel sst  13.0  1728.000
# 4       1                ford torino  11.5  1157.625

# %%
df1.head(2)
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
#
#    origin                       name  col1      col2
# 0       1  chevrolet chevelle malibu  13.0  1728.000
# 1       1          buick skylark 320  12.5  1520.875

# %%
12*12*12
# Out:
# 1728

# %%
12 **3
# Out:
# 1728

# %%
12 **4
# Out:
# 20736

# %%
12*12*12*12
# Out:
# 20736

# %%
12 **6
# Out:
# 2985984

# %%
12*12*12*12*12*12
# Out:
# 2985984

# %%
#Data Cleaaning

# %%
 # to chng from one data type to another type
 # astype : Vaild data type cahnages can be done using astype: int to float
 # to_numeric : to handle invaild numeric data type change

# %%
df1['col4']= df1['acceleration'].astype(int)
df1.head(2)
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
#
#    origin                       name  col1      col2  col4
# 0       1  chevrolet chevelle malibu  13.0  1728.000    12
# 1       1          buick skylark 320  12.5  1520.875    11

# %%
df1['col4']= df1['acceleration'].astype(int)
df1['Horse Power'].astype(int)
df1.head(2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 df1['col4']= df1['acceleration'].astype(int)
# ----> 2 df1['Horse Power'].astype(int)
#       3 df1.head(2)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
# ...

# %%
df1['Horse Power'].isnull().sum() #there are no missing values

# %%
df1['Horse Power'] = pd.to_numeric(df1['Horse Power'],errors = 'coerce') # this line is used for earse null values like eg.'?'
# coerce --> forceful --> if conversion is not possible remove that values(creating empty/blank)

# %%
df1['Horse Power'].isnull().sum()
 # after conversion 5 missing values

# %%
  df1.dtypes

# %%
## Missing values / Null sql/ Blanks / NaN/ Empty

# %%
# remove row where blank values
# replace Blank with something Else

# %%
df1.head(10)

# %%
383/397

# %%
head()
dropna() # you are asking pandas to remove blank row and return the data

# %%
df1.dropna()
# it is returning output (original df1 is not effected)
# df1 = df1.dropna() #to save your change to df1
#or
# df.dropna(inplace = true ) #commit() # make cahnges permanent on df1

# %%
df1.shape

# %%
#replace missing values

# %%
df1['mpg'].mean()

# %%
df1['mpg'] = df1['mpg'].fillna(23.611734693877548)
df1.head(10)

# %%
df1['mpg'] = df1['mpg'].fillna(df1['mpg'].mean()) # using function called fillna
df1.head(10) # we are observing is it applied or not # check

# %%
df1['displacement'] = df1['displacement'].fillna(df1['displacement'].mean())
df1.head(10)

# %%
df1.drop('col1',axis = 1, inplace = True)
df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df1.drop('col1',axis = 1, inplace = True)
#       2 df1
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
# ...

# %%
df1.drop(['col2','col4'], axis =1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df1.drop(['col2','col4'], axis =1, inplace = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...
